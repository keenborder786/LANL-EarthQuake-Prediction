# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
df=pd.read_csv("train.csv",nrows=10000000)

# %%
df.head()
# Out:
#    acoustic_data  time_to_failure
# 0             12           1.4691
# 1              6           1.4691
# 2              8           1.4691
# 3              5           1.4691
# 4              8           1.4691

# %%
ax = sns.distplot(df["acoustic_data"])

# %%
ax = sns.distplot(df["time_to_failure"])

# %%
ax = sns.jointplot(df["time_to_failure"], df["acoustic_data"], alpha=0.4)

# %%
ax=sns.pairplot(df)

# %%
fig1=plt.figure()
sns.boxplot(x=df["time_to_failure"])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig2=plt.figure()
ax2 = sns.boxplot(x=df["acoustic_data"])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
df_sample=df.sample(1000000)
fig3=plt.figure()
sns.violinplot(x=df_sample["time_to_failure"])

# %%
fig4=plt.figure()
sns.violinplot(x=df_sample["acoustic_data"])

# %%
df.corr()
# Out:
#                  acoustic_data  time_to_failure
# acoustic_data         1.000000        -0.003435
# time_to_failure      -0.003435         1.000000

# %%
df.describe()
# Out:
#        acoustic_data  time_to_failure
# count   1.000000e+07     1.000000e+07
# mean    4.502072e+00     5.183598e+00
# std     1.780707e+01     5.091286e+00
# min    -4.621000e+03     7.954798e-04
# 25%     2.000000e+00     6.498971e-01
# 50%     4.000000e+00     1.298899e+00
# 75%     7.000000e+00     1.089170e+01
# max     3.252000e+03     1.154080e+01

# %%
print(len(set(df["time_to_failure"])),len(set(df["acoustic_data"])))
# Out:
# 10000000 2065

# %%
print(len((df["time_to_failure"])),len((df["acoustic_data"])))
# Out:
# 10000000 10000000
